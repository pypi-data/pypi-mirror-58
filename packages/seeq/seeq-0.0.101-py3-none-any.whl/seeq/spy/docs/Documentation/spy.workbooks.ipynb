# %%
from seeq import spy
import pandas as pd

# %%
# Log into Seeq Server if you're not using Seeq Data Lab:
spy.login(url='http://localhost:34216', credentials_file='../credentials.key')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Logged in to <strong>http://localhost:34216/api</strong> successfully as <strong>mark.derbecker@seeq.com (Mark Derbecker [Admin])</strong></div>

# %% [markdown]
# # spy.workbooks
#
# The `spy.workbooks` module provides functions for importing and exporting _workbooks_. A workbook is either a _Workbench Analysis_ (colored green in the Seeq user interface) or an _Organizer Topic_ (colored blue).
#
# This functionality is helpful to:
#
# - Move content between two Seeq servers
# - Manage content by exporting and committing to a version control system like Git
#
# The process typically starts by searching for some content that you have created in Seeq and exporting it. However, since this documentation needs some pre-built content to illustrate how it works, there is a pre-built-and-exported set of workbooks alongside this documentation notebook. So we'll go in a non-typical order of operations in this example.

# %% [markdown]
# ## The Export Format
#
# When content is exported from Seeq, each workbook is encapsulated in its own folder, including all its worksheets, calculated item definitions and all dependencies, journal/document images and anything else that is necessary to import that data into another server. Content is written to disk as either JSON, HTML or image files as appropriate. References to datasource items are also catalogued during export and default _datasource maps_ are created that facilitate identification of equivalent signals/conditions/scalars on the destination system so that the imported content gets "hooked up" to the right data.

# %% [markdown]
# ## Main Actions
#
# There are five main operations you can perform on workbooks:
#
# - **search** for workbooks whose content you want to *pull*
# - **pull** those workbooks into `Workbook` in-memory Python objects
# - **save** the `Workbook` Python objects to disk in the export format described above
# - **load** `Workbook` Python objects from disk into memory
# - **push** in-memory `Workbook` Python objects into a Seeq Server
#
# As mentioned, we're going to go out-of-order for illustration purposes: _load_, _push_, _search_, _pull_, _save_.

# %% [markdown]
# ### Importing
#
# This set of documentation comes with an _Example Export_ folder that contains an Analysis and a Topic for illustration purposes. First we **load** it into memory:

# %%
workbooks = spy.workbooks.load('Example Export.zip')
workbooks
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Success</div>
# [Analysis Workbook "Example Analysis" (D833DC83-9A38-48DE-BF45-EB787E9E8375),
#  Topic Workbook "Example Topic" (811B1488-297A-4FD2-AE7C-A1FE0E3B3641)]

# %% [markdown]
# Now that the workbook definitions are in memory, we can push them into Seeq.

# %%
spy.workbooks.push(workbooks, path='My Import', errors='raise')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Push successful</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Workbook Type</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td><td style="background-color: #EEFFEE;">Pushed Workbook ID</td><td style="background-color: #EEFFEE;">Link</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>D833DC83-9A38-48DE-BF45-EB787E9E8375</td><td>Example Analysis</td><td>Analysis</td><td>73.0</td><td>00:00:03.80</td><td>Success</td><td>88330A19-FD1E-437F-A6E6-2C971DCAAA4C</td><td><a target="_blank" href="http://localhost:34216/2E3126F0-C541-4A02-8F82-56F7C5C58B79/workbook/88330A19-FD1E-437F-A6E6-2C971DCAAA4C/worksheet/92B1E4EA-2F5D-4937-BE82-3E4595BDB8AE">link</a></td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>811B1488-297A-4FD2-AE7C-A1FE0E3B3641</td><td>Example Topic</td><td>Topic</td><td>10.0</td><td>00:00:00.57</td><td>Success</td><td>4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9</td><td><a target="_blank" href="http://localhost:34216/2E3126F0-C541-4A02-8F82-56F7C5C58B79/workbook/4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9/worksheet/A5E88C8C-C456-4C34-BFE8-9F697E03F64A">link</a></td></tr></table>
#                                      ID              Name Workbook Type  \
# 0  D833DC83-9A38-48DE-BF45-EB787E9E8375  Example Analysis      Analysis
# 1  811B1488-297A-4FD2-AE7C-A1FE0E3B3641     Example Topic         Topic
#
#    Count            Time   Result                    Pushed Workbook ID  \
# 0   73.0  0:00:03.801897  Success  88330A19-FD1E-437F-A6E6-2C971DCAAA4C
# 1   10.0  0:00:00.572005  Success  4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9
#
#                                                 Link
# 0  http://localhost:34216/2E3126F0-C541-4A02-8F82...
# 1  http://localhost:34216/2E3126F0-C541-4A02-8F82...

# %% [markdown]
# The workbooks have been imported into Seeq in a _My Import_ folder with you as the owner. Refresh Seeq Workbench in your browser and take a look.

# %% [markdown]
# ### Exporting
#
# In Seeq Workbench, try changing the name of the _Example Analysis_ workbook to something like _My First Analysis Export_ so that you can tell that your changes get exported.
#
# Now we will **search** for the workbooks we want to export. The syntax for a workbook search query is very similar to an item metadata search via `spy.search()`:

# %%
workbooks_df = spy.workbooks.search({
    'Path': 'My Import'
})

workbooks_df
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Query successful.</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td></tr><tr style="background-color: #EEFFEE;"><td>Results</td><td>2</td><td>00:00:00.08</td></tr></table>
#    Access Level                           Created At  \
# 0  FULL_CONTROL  2019-12-14 00:25:38.869265100+00:00
# 1  FULL_CONTROL  2019-12-14 00:25:42.196265800+00:00
#
#                                      ID              Name  \
# 0  88330A19-FD1E-437F-A6E6-2C971DCAAA4C  Example Analysis
# 1  4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9     Example Topic
#
#                                Owner ID      Owner Name  \
# 0  C4D58EE0-DAB2-4052-A5E2-55C29D1B4E59  Mark Derbecker
# 1  C4D58EE0-DAB2-4052-A5E2-55C29D1B4E59  Mark Derbecker
#
#             Owner Username       Path  Pinned  \
# 0  mark.derbecker@seeq.com  My Import     0.0
# 1  mark.derbecker@seeq.com  My Import     0.0
#
#                        Search Folder ID      Type  \
# 0  2E3126F0-C541-4A02-8F82-56F7C5C58B79  Workbook
# 1  2E3126F0-C541-4A02-8F82-56F7C5C58B79  Workbook
#
#                             Updated At Workbook Type
# 0  2019-12-14 00:42:30.390085700+00:00      Analysis
# 1     2019-12-14 00:42:31.177086+00:00         Topic

# %% [markdown]
# As you can see, the `spy.workbooks.search()` command returns a metadata DataFrame with the properties of the workbooks. We can now use that to **pull**:

# %%
workbooks = spy.workbooks.pull(workbooks_df)
workbooks
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pull successful</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Workbook Type</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>88330A19-FD1E-437F-A6E6-2C971DCAAA4C</td><td>Example Analysis</td><td>Analysis</td><td>58</td><td>00:00:02.97</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9</td><td>Example Topic</td><td>Topic</td><td>6</td><td>00:00:00.47</td><td>Success</td></tr></table>
# [Analysis Workbook "Example Analysis" (88330A19-FD1E-437F-A6E6-2C971DCAAA4C),
#  Topic Workbook "Example Topic" (4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9)]

# %% [markdown]
# These are the same type of in-memory Python objects that we had when we executed `spy.workbooks.load()`. Now we can **save** them to disk:

# %%
spy.workbooks.save(workbooks, '../My First Export', clean=True)
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Success</div>

# %% [markdown]
# In the parent folder of this documentation notebook, you'll find a new _My First Export_ folder that contains similar files to the _Example Export_ folder that's part of the documentation.

# %% [markdown]
# ## Inspecting Worksheets
#
# With the in-memory Python objects that result from `spy.workbooks.pull()` or `spy.workbooks.load()`, you can inspect the worksheets to see what is displayed on them. For example, let's look at what's in the Details Pane of the second worksheet of _Example Analysis_:

# %%
worksheet_items = workbooks[0].worksheets[1].display_items
worksheet_items
# Out:
#   Axis Auto Scale Axis Group  \
# 0            True          A
# 1            True          A
# 2            True          C
# 3            True          D
# 4             NaN        NaN
# 5            True          A
#
#                                          Axis Limits    Color  \
# 0    {'min': 61.14466433825, 'max': 126.06745071175}  #068C45
# 1    {'min': 61.14466433825, 'max': 126.06745071175}  #9D248F
# 2  {'min': -4.0038206911, 'max': 42.169128111099994}  #CE561B
# 3    {'min': -120.6428567548, 'max': 117.2414925148}  #00A2DD
# 4                                                NaN  #4055A3
# 5    {'min': 61.14466433825, 'max': 126.06745071175}  #E1498E
#
#                                      ID  Lane   Line  Line Width  \
# 0  77B92A6B-2254-403F-907F-926B6E30464C   2.0  Solid         1.0
# 1  765C3C44-2295-4CA6-BFE1-FBBB82D02F51   2.0  Solid         2.5
# 2  A0AA5BAD-426B-4C82-AB3A-4A7FE686B1CE   1.0  Solid         1.0
# 3  DCCE108C-927A-4847-ADA1-578DFEE96FF3   3.0  Solid         1.0
# 4  8B0075AB-765C-4D36-8F62-B422F35B950B   NaN    NaN         NaN
# 5  B427418A-D9A5-49DB-BF10-62F2D3A521D5   2.0   Dash         1.0
#
#                       Name Right Axis Samples       Type
# 0       Area A_Temperature      False    Line     Signal
# 1       Smooth Temperature      False    Line     Signal
# 2  Area A_Compressor Power      False    Line     Signal
# 3       Area C_Temperature      False    Line     Signal
# 4               High Power        NaN     NaN  Condition
# 5        Temperature Limit      False     NaN     Scalar

# %% [markdown]
# Now you can call `spy.pull()` to pull data for the items in the worksheet.

# %%
spy.pull(worksheet_items, start='2019-01-01T00:00:00', end='2019-01-02T00:00:00')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pull successful from <strong>2019-01-01 00:00:00</strong> to <strong>2019-01-02 00:00:00</strong></div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>77B92A6B-2254-403F-907F-926B6E30464C</td><td>Area A_Temperature</td><td>97</td><td>00:00:00.05</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>765C3C44-2295-4CA6-BFE1-FBBB82D02F51</td><td>Smooth Temperature</td><td>97</td><td>00:00:00.19</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>2</td><td>A0AA5BAD-426B-4C82-AB3A-4A7FE686B1CE</td><td>Area A_Compressor Power</td><td>97</td><td>00:00:00.04</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td
# 2019-01-01 04:15:00+00:00         1.0         120.433655
# 2019-01-01 04:30:00+00:00         1.0         120.433655
# 2019-01-01 04:45:00+00:00         1.0         120.433655
# 2019-01-01 05:00:00+00:00         1.0         120.433655
# 2019-01-01 05:15:00+00:00         0.0         120.433655
# 2019-01-01 05:30:00+00:00         0.0         120.433655
# 2019-01-01 05:45:00+00:00         0.0         120.433655
# 2019-01-01 06:00:00+00:00         0.0         120.433655
# 2019-01-01 06:15:00+00:00         0.0         120.433655
# 2019-01-01 06:30:00+00:00         0.0         120.433655
# 2019-01-01 06:45:00+00:00         0.0         120.433655
# 2019-01-01 07:00:00+00:00         0.0         120.433655
# 2019-01-01 07:15:00+00:00         0.0         120.433655
# ...                               ...                ...
# 2019-01-01 16:45:00+00:00         0.0         120.433655
# 2019-01-01 17:00:00+00:00         0.0         120.433655
# 2019-01-01 17:15:00+00:00         0.0         120.433655
# 2019-01-01 17:30:00+00:00         0.0         120.433655
# 2019-01-01 17:45:00+00:00         0.0         120.433655
# 2019-01-01 18:00:00+00:00         0.0         120.433655
# 2019-01-01 18:15:00+00:00         0.0         120.433655
# 2019-01-01 18:30:00+00:00         0.0         120.433655
# 2019-01-01 18:45:00+00:00         0.0         120.433655
# 2019-01-01 19:00:00+00:00         0.0         120.433655
# 2019-01-01 19:15:00+00:00         0.0         120.433655
# 2019-01-01 19:30:00+00:00         0.0         120.433655
# 2019-01-01 19:45:00+00:00         0.0         120.433655
# 2019-01-01 20:00:00+00:00         0.0         120.433655
# 2019-01-01 20:15:00+00:00         0.0         120.433655
# 2019-01-01 20:30:00+00:00         0.0         120.433655
# 2019-01-01 20:45:00+00:00         0.0         120.433655
# 2019-01-01 21:00:00+00:00         0.0         120.433655
# 2019-01-01 21:15:00+00:00         0.0         120.433655
# 2019-01-01 21:30:00+00:00         0.0         120.433655
# 2019-01-01 21:45:00+00:00         0.0         120.433655
# 2019-01-01 22:00:00+00:00         0.0         120.433655
# 2019-01-01 22:15:00+00:00         0.0         120.433655
# 2019-01-01 22:30:00+00:00         0.0         120.433655
# 2019-01-01 22:45:00+00:00         0.0         120.433655
# 2019-01-01 23:00:00+00:00         0.0         120.433655
# 2019-01-01 23:15:00+00:00         0.0         120.433655
# 2019-01-01 23:30:00+00:00         0.0         120.433655
# 2019-01-01 23:45:00+00:00         0.0         120.433655
# 2019-01-02 00:00:00+00:00         0.0         120.433655
#
# [97 rows x 6 columns]

# %% [markdown]
# Note that if you just wanted the full metadata for the items, you could execute `spy.search(worksheet_items[['ID']])`.

# %% [markdown]
# ## Re-importing and Labels
#
# If you **push** a set of workbooks more than once, then by default you will simply overwrite the existing workbooks with the saved content. This can be useful when you are "backing up" content to disk, perhaps for the purposes of version control.
#
# You can choose to **push** and supply a _label_, which will create a separate copy of all of the imported items instead of modifying the existing ones. This is useful when you want to import something that you are iterating on prior to affecting the "published" version. For example, let's push our workbooks with the label of `In Development`:

# %%
spy.workbooks.push(workbooks, path='My Development Folder', label='In Development')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Push successful</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Workbook Type</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td><td style="background-color: #EEFFEE;">Pushed Workbook ID</td><td style="background-color: #EEFFEE;">Link</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>88330A19-FD1E-437F-A6E6-2C971DCAAA4C</td><td>Example Analysis</td><td>Analysis</td><td>63.0</td><td>00:00:02.53</td><td>Success</td><td>31F5A7C5-72FF-45CF-90B9-C97CE848D7C9</td><td><a target="_blank" href="http://localhost:34216/8BFF08EE-9AAF-47D8-94C0-B0B396DB70AA/workbook/31F5A7C5-72FF-45CF-90B9-C97CE848D7C9/worksheet/5C020A4E-F652-47A3-B1C9-F8261F5F8116">link</a></td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9</td><td>Example Topic</td><td>Topic</td><td>6.0</td><td>00:00:00.31</td><td>Success</td><td>3BB843BF-46BD-4271-80B8-52A6A06793B9</td><td><a target="_blank" href="http://localhost:34216/8BFF08EE-9AAF-47D8-94C0-B0B396DB70AA/workbook/3BB843BF-46BD-4271-80B8-52A6A06793B9/worksheet/AECBDB4E-F817-4A62-BB7C-C2C88DA51304">link</a></td></tr></table>
#                                      ID              Name Workbook Type  \
# 0  88330A19-FD1E-437F-A6E6-2C971DCAAA4C  Example Analysis      Analysis
# 1  4A2FEFBE-7F95-49C2-B90D-5835F77D6AB9     Example Topic         Topic
#
#    Count            Time   Result                    Pushed Workbook ID  \
# 0   63.0  0:00:02.534000  Success  31F5A7C5-72FF-45CF-90B9-C97CE848D7C9
# 1    6.0  0:00:00.311998  Success  3BB843BF-46BD-4271-80B8-52A6A06793B9
#
#                                                 Link
# 0  http://localhost:34216/8BFF08EE-9AAF-47D8-94C0...
# 1  http://localhost:34216/8BFF08EE-9AAF-47D8-94C0...

# %% [markdown]
# If you refresh Seeq Workbench, you'll notice that there is now a _My Development Folder_ and a separate copy of the Topic and Analysis that is independent of the original -- including all calculated items.
#
# Pushing with the same value for the `label` argument will overwrite the content for that label. Change the label again if you want yet another separate copy.

# %% [markdown]
# ## Importing to a Different Seeq Server
#
# You may wish to copy content to a new/different Seeq Server by exporting and then importing. For example, you might have a _development_ server where you iterate on content and a _production_ server that you publish to when finished.
#
# In order to accomplish this, you'll do one of two actions:
#
# - If you're using the Spy library within Seeq Data Lab, you'll copy the exported folder to the other version of Seeq Data Lab and then push it from there.
# - If you're using the Spy library with your own Python set up, you'll log in to the other server and push it.
