# %%
from pymcs import io

# %%
df = io.read_header_data('1506')

# %%
df.shape
# Out:
# (63977, 81)

# %%
timestring = '08030100'

# %%
db = io.DBManager()

# %%
db.timestring
# Out:
# '000000000000'

# %%
db.timestring = timestring

# %%
db.timestring
# Out:
# '080301000000'

# %%
db.get_day('profiles', '160101')
# Out:
# 100%|██████████| 6/6 [00:06<00:00,  1.13s/it]
#                Pres   T  T_error  Dust  Dust_error  H2Oice  H2Oice_error  \
# 0       1878.932000 NaN      NaN   NaN         NaN     NaN           NaN
# 1       1658.152000 NaN      NaN   NaN         NaN     NaN           NaN
# 2       1463.314000 NaN      NaN   NaN         NaN     NaN           NaN
# 3       1291.370000 NaN      NaN   NaN         NaN     NaN           NaN
# 4       1139.630000 NaN      NaN   NaN         NaN     NaN           NaN
# ...             ...  ..      ...   ...         ...     ...           ...
# 233935     0.007002 NaN      NaN   NaN         NaN     NaN           NaN
# 233936     0.006179 NaN      NaN   NaN         NaN     NaN           NaN
# 233937     0.005453 NaN      NaN   NaN         NaN     NaN           NaN
# 233938     0.004812 NaN      NaN   NaN         NaN     NaN           NaN
# 233939     0.004247 NaN      NaN   NaN         NaN     NaN           NaN
#
# ...

# %%
[col for col in db.read_4h_header(timestring).columns if 'ust' in col]
# Out:
# ['Dust_463_nad_od', 'Dust_463_nad_od_err', 'Dust qual']

# %%
[col for col in db.read_4h_rms().columns if 'ust' in col]
# Out:
# ['Dust_rms']

# %%
db.read_4h_
# Out:
#       Channel  Radiance_measured  Radiance_calculated  Altitude
# 0           1          47.827332            47.177250       4.5
# 1           2          27.403334            27.762299      13.5
# 2           3          13.562667            13.575129      25.5
# 3           4          48.582836                  NaN       NaN
# 4           5          85.423340                  NaN       NaN
# ...       ...                ...                  ...       ...
# 4036        5          83.084663                  NaN       NaN
# 4037        6          10.713166                  NaN       NaN
# 4038        7          68.598167            68.596619       0.0
# 4039        8          53.205830                  NaN       NaN
# 4040        9          51.900330                  NaN       NaN
#
# [4041 rows x 4 columns]

# %%
db.read_4h_limb()
# Out:
#        Channel  Detector  Radiance_measured  Radiance_calculated  Altitude
# 0            1         1             0.3792                  NaN       NaN
# 1            1         2             0.3050                  NaN       NaN
# 2            1         3             0.3732                  NaN       NaN
# 3            1         4             0.3772                  NaN       NaN
# 4            1         5             0.3618                  NaN       NaN
# ...        ...       ...                ...                  ...       ...
# 84856        9        17             1.4848                  NaN       NaN
# 84857        9        18             1.2860                  NaN       NaN
# 84858        9        19             1.2794                  NaN       NaN
# 84859        9        20             1.6166                  NaN       NaN
# 84860        9        21             2.0824                  NaN       NaN
#
# [84861 rows x 5 columns]

# %%
db.read_4h_profiles()
# Out:
#               Pres   T  T_error  Dust  Dust_error  H2Oice  H2Oice_error  \
# 0      1878.932000 NaN      NaN   NaN         NaN     NaN           NaN
# 1      1658.152000 NaN      NaN   NaN         NaN     NaN           NaN
# 2      1463.314000 NaN      NaN   NaN         NaN     NaN           NaN
# 3      1291.370000 NaN      NaN   NaN         NaN     NaN           NaN
# 4      1139.630000 NaN      NaN   NaN         NaN     NaN           NaN
# ...            ...  ..      ...   ...         ...     ...           ...
# 47140     0.007002 NaN      NaN   NaN         NaN     NaN           NaN
# 47141     0.006179 NaN      NaN   NaN         NaN     NaN           NaN
# 47142     0.005453 NaN      NaN   NaN         NaN     NaN           NaN
# 47143     0.004812 NaN      NaN   NaN         NaN     NaN           NaN
# 47144     0.004247 NaN      NaN   NaN         NaN     NaN           NaN
#
#        H2Ovap  H2Ovap_error  CO2ice  CO2ice_error      Alt     Lat     Lon
# ...
